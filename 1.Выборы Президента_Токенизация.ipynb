# %%
import pandas as pd
import numpy as np

# %%
import string
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pymorphy3

# %%
df_posts = pd.read_csv('posts.csv')
df_posts.head()
# Out:
#    Unnamed: 0  post_id                                          post_text
# 0           0    12103  Итак 2024 наступил и скоро выборы, за кого гол...
# 1           1    12266  Последнего реального кандидата от оппозиции и ...
# 2           2    12228  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3           3    12191  Не допущен к выборам, по опросам у него не бол...
# 4           4    12183  Более не сможет быть кандидатом в Президенты -...

# %%
df_comments = pd.read_csv('comments.csv')
df_comments.head()
# Out:
#    Unnamed: 0  post_id                                      comments_text
# 0           0  12103.0  Зачем эта игра в "демократию" ?! Результат уже...
# 1           1  12103.0                  За Бориса Борисовича Надеждина!!!
# 2           5  12103.0       Я бы вообще , голосовал за Ярослава Нилова !
# 3           6  12103.0  Интересно, если бы хоть раз выборы прошли чест...
# 4           7  12103.0          Выборы - без выбора. Вообще не за кого!!!

# %% [markdown]
# **ТОКЕНИЗАЦИЯ ТЕКСТА**

# %%
stop_words = stopwords.words('russian')
morph = pymorphy3.MorphAnalyzer()

# %%
def tokenize_text(raw_text: str):
    """Функция для токенизации текста
    :param raw_text: исходная текстовая строка
    """
    # Разбиение на сслова при помощи пробела
    words = raw_text.split()
    # Подготовка регулярного выражения для фильтрации символов
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # Удаление знаков препинания
    stripped = [re_punc.sub('', w) for w in words]
    # Приведение всех слов к нижнему регистру
    words_lower = [w.lower() for w in stripped]
    # Удаление оставшихся токенов, которые не являются буквами
    words_alpha = [word for word in words_lower if word.isalpha()]
    # Удаление стоп-слов    
    words_stop = [w for w in words_alpha if not w in stop_words]
    # Лемматизация    
    tokens = [morph.parse(token)[0].normal_form for token in words_stop]
    # Удалим короткие токены
    tokens = [word for word in tokens if len(word) > 1]

    return tokens

# %% [markdown]
# **1. Токенизация постов Сообщества "Выборы Президента России 2024"**

# %%
# применяем функцию к датафрейму с помощью метода .apply()
tokenized= df_posts.post_text.apply(tokenize_text)

# %%
# добавляем новую колонку в исходный датафрейм
df_posts = df_posts.assign(tokenized=tokenized)
df_posts.head()
# Out:
#    Unnamed: 0  post_id                                          post_text  \
# 0           0    12103  Итак 2024 наступил и скоро выборы, за кого гол...
# 1           1    12266  Последнего реального кандидата от оппозиции и ...
# 2           2    12228  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3           3    12191  Не допущен к выборам, по опросам у него не бол...
# 4           4    12183  Более не сможет быть кандидатом в Президенты -...
#
#                                            tokenized
# 0  [итак, наступить, скоро, выборы, кто, голосовать]
# 1  [последний, реальный, кандидат, оппозиция, либ...
# 2  [минутка, оппозиция, еlеn, байден, пoпpиветcтв...
# 3  [допустить, выборы, опрос, последователь, увер...
# 4  [смочь, кандидат, президент, умереть, колония,...

# %% [markdown]
# **2. Токенизация комментариев к постам Сообщества "Выборы Президента России 2024"**

# %%
# применяем функцию к датафрейму с помощью метода .apply()
tokenized= df_comments.comments_text.apply(tokenize_text)

# %%
# добавляем новую колонку в исходный датафрейм
df_comments = df_comments.assign(tokenized=tokenized)
df_comments.head()
# Out:
#    Unnamed: 0  post_id                                      comments_text  \
# 0           0  12103.0  Зачем эта игра в "демократию" ?! Результат уже...
# 1           1  12103.0                  За Бориса Борисовича Надеждина!!!
# 2           5  12103.0       Я бы вообще , голосовал за Ярослава Нилова !
# 3           6  12103.0  Интересно, если бы хоть раз выборы прошли чест...
# 4           7  12103.0          Выборы - без выбора. Вообще не за кого!!!
#
#                                            tokenized
# 0  [этот, игра, демократия, результат, итак, изве...
# 1                       [борис, борисович, надеждин]
# 2             [вообще, голосовать, ярослав, ниловый]
# 3  [интересно, выборы, пройти, честно, расклад, д...
# 4                       [выборы, выбор, вообще, кто]

# %%
df_posts = pd.read_csv('posts_tokenised.csv')
df_posts.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  post_id  \
# 0             0           0    12103
# 1             1           1    12266
# 2             2           2    12228
# 3             3           3    12191
# 4             4           4    12183
#
#                                            post_text  \
# 0  Итак 2024 наступил и скоро выборы, за кого гол...
# 1  Последнего реального кандидата от оппозиции и ...
# 2  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3  Не допущен к выборам, по опросам у него не бол...
# 4  Более не сможет быть кандидатом в Президенты -...
#
#                                            tokenized  \
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...
# 3  ['допустить', 'выборы', 'опрос', 'последовател...
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...
#
#                                               tokens
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...
# 3  ['допустить', 'выборы', 'опрос', 'последовател...
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...

# %% [markdown]
# **Разведочный анализ данных**

# %% [markdown]
# **1. Посты сообщества "Выборы Президенрта России 2024"**

# %%
from nltk.probability import FreqDist

# %%
words_list_posts = list(df_posts['tokens'])

# %%
#all_words_posts = np.concatenate(words_list_posts)

all_words_freq_posts = FreqDist(words_list_posts)

print("Наиболлее популярные слова: ", all_words_freq_posts.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words_freq_posts.keys()))
# Out:
# Наиболлее популярные слова:  [("['биография', 'история', 'жизнь', 'владимир', 'владимирович', 'путин', 'детство', 'юность', 'родиться', 'октябрь', 'ленинград', 'согласно', 'собственный', 'ответ', 'время', 'перепись', 'население', 'русский', 'национальный', 'принадлежность', 'отец', 'путин', 'владимир', 'спиридонович', 'путин', 'участник', 'вов', 'боец', 'стрелковый', 'полка', 'дивизия', 'красный', 'армия', 'воевать', 'защищать', 'невский', 'пятачок', 'тяжело', 'ранить', 'война', 'служить', 'подводный', 'флот', 'война', 'мастер', 'завод', 'егоров', 'мать', 'мария', 'иванович', 'шеломов', 'также', 'работать', 'завод', 'пережить', 'блокада', 'ленинград', 'дед', 'спиридон', 'иванович', 'путин', 'известный', 'повар', 'готовить', 'высокий', 'партийный', 'государственный', 'чин', 'приходиться', 'готовить', 'ленин', 'сталин', 'владимир', 'третий', 'сын', 'семья', 'двое', 'старший', 'брат', 'родиться', 'ещё', 'тридцатый', 'умереть', 'детство', 'стать', 'известно', 'один', 'брат', 'звать', 'виктор', 'родиться', 'умереть', 'дифтерия', 'похоронный', 'пискарёвский', 'кладбище', 'семья', 'путин', 'жить', 'коммунальный', 'квартира', 'басков', 'переулок', 'ленинград', 'стать', 'президент', 'путин', 'рассказывать', 'ещё', 'детство', 'увлекаться', 'советский', 'фильм', 'разведчик', 'мечтать', 'работать', 'орган', 'государственный', 'безопасность', 'учиться', 'международный', 'отделение', 'юридический', 'факультет', 'ленинградский', 'государственный', 'университет', 'имя', 'жданов', 'лгать', 'лгать', 'вступить', 'кпсс', 'запретить', 'партия', 'выходить', 'время', 'учёба', 'впервые', 'встретить', 'анатолий', 'собчак', 'время', 'доцент', 'лгать', 'тема', 'диплом', 'наиболее', 'благоприятствуемый', 'научий', 'рука', 'галенский', 'людмила', 'никифорович', 'кафедра', 'международный', 'право', 'служба', 'кгб', 'закончить', 'юридический', 'факультет', 'лгать', 'распределение', 'направить', 'работа', 'комитет', 'государственный', 'безопасность', 'окончить', 'подготовка', 'оперативный', 'охта', 'аттестовать', 'младший', 'офицер', 'старший', 'лейтенант', 'юстиция', 'система', 'территориальный', 'орган', 'кгб', 'ссср', 'работать', 'линия', 'контрразведка', 'следственный', 'отдел', 'ленинградский', 'управление', 'кгб', 'закончить', 'обучение', 'шестимесячный', 'курс', 'переподготовка', 'высокий', 'школа', 'кгб', 'москва', 'снова', 'вернуться', 'ленинград', 'звание', 'майор', 'юстиция', 'откомандировать', 'обучение', 'одногодичный', 'факультет', 'краснознамённый', 'андропов', 'институт', 'кгб', 'ссср', 'окончить', 'специальность', 'ки', 'кгб', 'ссср', 'носить', 'фамилия', 'плат', 'староста', 'учебный', 'отделение', 'изучать', 'немецкий', 'язык', 'работать', 'гдр', 'проходить', 'служба', 'территориальный', 'разведточка', 'дрезден', 'прикрытие', 'должность', 'директор', 'дрезденский', 'дом', 'дружба', 'сссргдр', 'течение', 'командировка', 'выслуга', 'повысить', 'звание', 'подполковник', 'должность', 'старший', 'помощник', 'начальник', 'отдел', 'наградить', 'бронзовый', 'медаль', 'заслуга', 'национальный', 'народный', 'армия', 'окончание', 'загранкомандировка', 'возвращение', 'ссср', 'слово', 'путин', 'добровольно', 'отказаться', 'переход', 'центральный', 'аппарат', 'внешний', 'разведка', 'кгб', 'ссср', 'москва', 'снова', 'вернуться', 'штат', 'первый', 'отдел', 'разведка', 'территория', 'ссср', 'ленинградский', 'управление', 'кгб', 'слово', 'путин', 'дважды', 'подавать', 'рапорт', 'увольнение', 'орган', 'кгб', 'ссср', 'переход', 'работа', 'мэрия', 'ленинград', 'август', 'время', 'выступление', 'собчак', 'против', 'гкчп', 'путин', 'написать', 'рапорт', 'увольнение', 'кгб', 'работа', 'санктпетербург', 'начало', 'весна', 'основный', 'официальный', 'место', 'работа', 'ленинградский', 'государственный', 'университет', 'лгать', 'жданов', 'лгать', 'путин', 'стать', 'помощник', 'ректор', 'станислав', 'меркурьев', 'международный', 'вопрос', 'меркурьев', 'поздний', 'рекомендовать', 'анатолий', 'собчак', 'путин', 'исполнительный', 'работник', 'май', 'советник', 'председат ...
#
# Общее количество уникальных слов:  391

# %%
count, words = [], []
for w in all_words_freq_posts.most_common(10):
    words.append(w[0])
    count.append(w[1])

ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов для постов сообщества "Выборы Президента России 2024')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
stop_words_ex = ['год','это', 'который']
def stop_words_extra(text):
    return [w for w in text if not w in stop_words_ex]

# %%
# применяем функцию к датафрейму с помощью метода .apply()
tokens = df_posts.tokenized.apply(stop_words_extra)

# %%
# добавляем новую колонку в исходный датафрейм
df_posts = df_posts.assign(tokens=tokens)
df_posts.head()
# Out:
#    Unnamed: 0  post_id                                          post_text  \
# 0           0    12103  Итак 2024 наступил и скоро выборы, за кого гол...
# 1           1    12266  Последнего реального кандидата от оппозиции и ...
# 2           2    12228  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3           3    12191  Не допущен к выборам, по опросам у него не бол...
# 4           4    12183  Более не сможет быть кандидатом в Президенты -...
#
#                                            tokenized  \
# 0  [итак, наступить, скоро, выборы, кто, голосовать]
# 1  [последний, реальный, кандидат, оппозиция, либ...
# 2  [минутка, оппозиция, еlеn, байден, пoпpиветcтв...
# 3  [допустить, выборы, опрос, последователь, увер...
# 4  [смочь, кандидат, президент, умереть, колония,...
#
#                                               tokens
# 0  [итак, наступить, скоро, выборы, кто, голосовать]
# 1  [последний, реальный, кандидат, оппозиция, либ...
# 2  [минутка, оппозиция, еlеn, байден, пoпpиветcтв...
# 3  [допустить, выборы, опрос, последователь, увер...
# 4  [смочь, кандидат, президент, умереть, колония,...

# %%
words_list_posts_new = list(df_posts['tokens'])

# %%
all_words_posts_new = np.concatenate(words_list_posts_new)

all_words_freq_posts_new = FreqDist(all_words_posts_new)

print("Наиболлее популярные слова: ", all_words_freq_posts_new.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words_freq_posts_new.keys()))
# Out:
# Наиболлее популярные слова:  [('путин', 8292), ('президент', 6977), ('россия', 5312), ('российский', 5249), ('зюганов', 4758), ('председатель', 4082), ('государственный', 3955), ('федерация', 3522), ('стать', 3433), ('владимир', 2982), ('правительство', 2900), ('должность', 2843), ('первый', 2593), ('свой', 2472), ('совет', 2462), ('сергей', 2405), ('партия', 2347), ('комитет', 2347), ('выборы', 2238), ('заместитель', 2226), ('работа', 2216), ('пост', 2130), ('май', 2073), ('назначить', 2034), ('глава', 2013), ('рф', 1931), ('также', 1840), ('управление', 1806), ('депутат', 1762), ('экономический', 1757), ('санктпетербург', 1757), ('га', 1704), ('дума', 1692), ('республика', 1691), ('работать', 1670), ('связь', 1665), ('март', 1656), ('ссср', 1642), ('руководитель', 1635), ('вопрос', 1623), ('ельцин', 1516), ('время', 1500), ('город', 1416), ('декабрь', 1398), ('кгб', 1397), ('политический', 1392), ('страна', 1379), ('международный', 1378), ('комиссия', 1299), ('власть', 1296), ('институт', 1289), ('шойгу', 1284), ('область', 1283), ('август', 1268), ('член', 1241), ('родиться', 1234), ('отдел', 1219), ('дмитрий', 1196), ('избрать', 1181), ('министр', 1170), ('фракция', 1153), ('созыв', 1133), ('фсб', 1124), ('новый', 1122), ('федеральный', 1111), ('безопасность', 1110), ('кужугетович', 1071), ('москва', 1068), ('проект', 1058), ('михаил', 1056), ('государство', 1046), ('факультет', 1033), ('явлинский', 1030), ('собчак', 1021), ('андрей', 1018), ('дело', 1006), ('кпрф', 999), ('школа', 994), ('съезд', 982), ('кадыров', 977), ('президентский', 975), ('чеченский', 975), ('окончить', 967), ('русский', 965), ('сентябрь', 964), ('кпсс', 959), ('кандидат', 954), ('человек', 928), ('орган', 926), ('против', 917), ('медаль', 915), ('наука', 913), ('союз', 911), ('университет', 906), ('экономика', 905), ('качество', 903), ('центральный', 902), ('затем', 898), ('почётный', 882), ('геннадий', 879)]
#
# Общее количество уникальных слов:  4622

# %%
count, words = [], []
for w in all_words_freq_posts_new.most_common(10):
    words.append(w[0])
    count.append(w[1])

ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов для постов из сообщества "Выборы Президента России"')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# **2. Комменитарии к постам сообщества "Выборы Президенрта России 2024"**

# %%
# применяем функцию к датафрейму с помощью метода .apply()
tokens = df_comments.tokenized.apply(stop_words_extra)

# %%
df_comments = df_comments.assign(tokens=tokens)
df_comments.head()
# Out:
#    Unnamed: 0  post_id                                      comments_text  \
# 0           0  12103.0  Зачем эта игра в "демократию" ?! Результат уже...
# 1           1  12103.0                  За Бориса Борисовича Надеждина!!!
# 2           5  12103.0       Я бы вообще , голосовал за Ярослава Нилова !
# 3           6  12103.0  Интересно, если бы хоть раз выборы прошли чест...
# 4           7  12103.0          Выборы - без выбора. Вообще не за кого!!!
#
#                                            tokenized  \
# 0  [этот, игра, демократия, результат, итак, изве...
# 1                       [борис, борисович, надеждин]
# 2             [вообще, голосовать, ярослав, ниловый]
# 3  [интересно, выборы, пройти, честно, расклад, д...
# 4                       [выборы, выбор, вообще, кто]
#
#                                               tokens
# 0  [этот, игра, демократия, результат, итак, изве...
# 1                       [борис, борисович, надеждин]
# 2             [вообще, голосовать, ярослав, ниловый]
# 3  [интересно, выборы, пройти, честно, расклад, д...
# 4                       [выборы, выбор, вообще, кто]

# %%
words_list_comments = list(df_comments['tokens'])

# %%
all_words_comments = np.concatenate(words_list_comments)

all_words_freq_comments = FreqDist(all_words_comments)

print("Наиболлее популярные слова: ", all_words_freq_comments.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words_freq_comments.keys()))
# Out:
# Наиболлее популярные слова:  [('путин', 1070), ('россия', 864), ('свой', 774), ('человек', 685), ('грудинин', 602), ('наш', 595), ('страна', 591), ('народ', 545), ('президент', 484), ('деньга', 418), ('весь', 392), ('выборы', 385), ('такой', 369), ('власть', 322), ('быть', 310), ('всё', 303), ('один', 300), ('жить', 290), ('государство', 279), ('знать', 273), ('русский', 272), ('говорить', 261), ('кандидат', 260), ('время', 258), ('сам', 254), ('сделать', 252), ('просто', 249), ('голосовать', 245), ('хотеть', 232), ('делать', 230), ('тот', 228), ('навальный', 227), ('каждый', 219), ('другой', 218), ('мочь', 214), ('новый', 210), ('должный', 204), ('стать', 200), ('мы', 196), ('какой', 190), ('вообще', 178), ('война', 176), ('иметь', 174), ('кто', 169), ('сказать', 169), ('ваш', 168), ('очень', 168), ('почему', 166), ('работать', 165), ('против', 164), ('этот', 159), ('мир', 158), ('сша', 156), ('гражданин', 155), ('идти', 154), ('никто', 154), ('дать', 154), ('нужно', 154), ('день', 153), ('работа', 153), ('ещё', 152), ('друг', 152), ('система', 149), ('нужный', 146), ('рф', 144), ('российский', 143), ('жизнь', 143), ('дело', 141), ('видеть', 140), ('самый', 138), ('зарплата', 137), ('украина', 137), ('программа', 135), ('первый', 135), ('развитие', 130), ('общий', 128), ('думать', 124), ('смотреть', 124), ('хороший', 123), ('ребёнок', 119), ('москва', 118), ('партия', 116), ('вопрос', 113), ('право', 113), ('запад', 112), ('ссср', 111), ('место', 110), ('закон', 110), ('павел', 110), ('либо', 109), ('территория', 108), ('слово', 107), ('писать', 106), ('понимать', 104), ('получить', 103), ('начать', 102), ('понять', 101), ('голос', 100), ('план', 99), ('выбор', 98)]
#
# Общее количество уникальных слов:  14690

# %%
count, words = [], []
for w in all_words_freq_comments.most_common(10):
    words.append(w[0])
    count.append(w[1])

ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов для комментариев к постам сообщества "Выборы Президента России 2024')
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
df_posts.to_csv('posts_tokenised.csv')

# %%
df_comments.to_csv('comments_tokenised.csv')
