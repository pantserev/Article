# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
df = pd.read_csv('posts_tokenised.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  post_id  \
# 0             0           0    12103
# 1             1           1    12266
# 2             2           2    12228
# 3             3           3    12191
# 4             4           4    12183
#
#                                            post_text  \
# 0  Итак 2024 наступил и скоро выборы, за кого гол...
# 1  Последнего реального кандидата от оппозиции и ...
# 2  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3  Не допущен к выборам, по опросам у него не бол...
# 4  Более не сможет быть кандидатом в Президенты -...
#
#                                            tokenized  \
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...
# 3  ['допустить', 'выборы', 'опрос', 'последовател...
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...
#
#                                               tokens
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...
# 3  ['допустить', 'выборы', 'опрос', 'последовател...
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...

# %%
df.shape
# Out:
# (2294, 6)

# %% [markdown]
# **Латантное распределение Дирихле (LDA)**

# %%
count_vect = CountVectorizer(max_df=0.8, min_df=3, stop_words=None)
doc_term_matrix = count_vect.fit_transform(df['tokens'].values.astype('U'))
doc_term_matrix
# Out:
# <2294x2804 sparse matrix of type '<class 'numpy.int64'>'
# 	with 302931 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **2 темы**

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['санктпетербург', 'работа', 'государственный', 'правительство', 'владимир', 'председатель', 'российский', 'россия', 'президент', 'путин']
#
#
# Top 10 words for topic #1:
# ['га', 'председатель', 'стать', 'сергей', 'государственный', 'федерация', 'россия', 'российский', 'президент', 'зюганов']

# %% [markdown]
# **3 темы**

# %%
LDA = LatentDirichletAllocation(n_components=3, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['рф', 'государственный', 'фракция', 'стать', 'председатель', 'прохоров', 'андрей', 'совет', 'проект', 'экономический']
#
#
# Top 10 words for topic #1:
# ['геннадий', 'стать', 'чеченский', 'кадыров', 'выборы', 'кпрф', 'россия', 'президент', 'га', 'зюганов']
#
#
# Top 10 words for topic #2:
# ['сергей', 'правительство', 'владимир', 'председатель', 'государственный', 'федерация', 'россия', 'российский', 'президент', 'путин']

# %% [markdown]
# **4 темы**

# %%
LDA = LatentDirichletAllocation(n_components=4, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=4, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['явлинский', 'труд', 'воробей', 'фракция', 'стать', 'прохоров', 'председатель', 'андрей', 'совет', 'экономический']
#
#
# Top 10 words for topic #1:
# ['республика', 'геннадий', 'стать', 'чеченский', 'кадыров', 'кпрф', 'россия', 'президент', 'га', 'зюганов']
#
#
# Top 10 words for topic #2:
# ['работа', 'федерация', 'владимир', 'сергей', 'правительство', 'председатель', 'российский', 'россия', 'президент', 'путин']
#
#
# Top 10 words for topic #3:
# ['выборы', 'жириновский', 'почётный', 'проект', 'дума', 'владимир', 'президент', 'федерация', 'российский', 'государственный']

# %% [markdown]
# **Лучшая модель: 2 темы**

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['санктпетербург', 'работа', 'государственный', 'правительство', 'владимир', 'председатель', 'российский', 'россия', 'президент', 'путин']
#
#
# Top 10 words for topic #1:
# ['га', 'председатель', 'стать', 'сергей', 'государственный', 'федерация', 'россия', 'российский', 'президент', 'зюганов']

# %%
topic_values = LDA.transform(doc_term_matrix)
topic_values.shape
# Out:
# (2294, 2)

# %%
df['Topic_LDA'] = topic_values.argmax(axis=1)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  post_id  \
# 0             0           0    12103
# 1             1           1    12266
# 2             2           2    12228
# 3             3           3    12191
# 4             4           4    12183
#
#                                            post_text  \
# 0  Итак 2024 наступил и скоро выборы, за кого гол...
# 1  Последнего реального кандидата от оппозиции и ...
# 2  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3  Не допущен к выборам, по опросам у него не бол...
# 4  Более не сможет быть кандидатом в Президенты -...
#
#                                            tokenized  \
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...
# 3  ['допустить', 'выборы', 'опрос', 'последовател...
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...
#
#                                               tokens  Topic_LDA
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...          1
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...          0
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...          0
# 3  ['допустить', 'выборы', 'опрос', 'последовател...          1
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...          0

# %%
plt.hist(df['Topic_LDA'])
plt.xticks([0, 1]);

# %%
topic_1 = df[df['Topic_LDA']==0]
topic_1.shape
# Out:
# (1259, 7)

# %%
topic_2 = df[df['Topic_LDA']==1]
topic_2.shape
# Out:
# (1035, 7)

# %%
textt = ''.join(w for w in topic_1.tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_2.tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **Неотрицательная матричная факторизация (NMF)**

# %%
tfidf_vect = TfidfVectorizer(max_df=1.0, min_df=2, stop_words=None)
doc_term_matrix = tfidf_vect.fit_transform(df['tokens'].values.astype('U'))

# %% [markdown]
# **2 темы**

# %%
nmf = NMF(n_components=2, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(n_components=2, random_state=42)

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['партия', 'государственный', 'председатель', 'федерация', 'владимир', 'явлинский', 'россия', 'российский', 'президент', 'путин']
#
#
# Top 10 words for topic #1:
# ['мочь', 'призывать', 'геннадий', 'андреевич', 'репост', 'кпрф', 'га', 'зюганов', 'поход', 'ставить']

# %% [markdown]
# **3 темы**

# %%
nmf = NMF(n_components=3, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(n_components=3, random_state=42)

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['проект', 'правительство', 'государственный', 'председатель', 'федерация', 'владимир', 'россия', 'российский', 'президент', 'путин']
#
#
# Top 10 words for topic #1:
# ['мочь', 'призывать', 'геннадий', 'андреевич', 'репост', 'кпрф', 'га', 'зюганов', 'поход', 'ставить']
#
#
# Top 10 words for topic #2:
# ['президент', 'выдвижение', 'состояться', 'свет', 'увидеть', 'яблоко', 'кандидат', 'григорий', 'партия', 'явлинский']

# %% [markdown]
# **3 темы: визуализация**

# %%
topic_values = nmf.transform(doc_term_matrix)
topic_values.shape
# Out:
# (2294, 3)

# %%
df['Topic_NMF'] = topic_values.argmax(axis=1)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  post_id  \
# 0             0           0    12103
# 1             1           1    12266
# 2             2           2    12228
# 3             3           3    12191
# 4             4           4    12183
#
#                                            post_text  \
# 0  Итак 2024 наступил и скоро выборы, за кого гол...
# 1  Последнего реального кандидата от оппозиции и ...
# 2  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3  Не допущен к выборам, по опросам у него не бол...
# 4  Более не сможет быть кандидатом в Президенты -...
#
#                                            tokenized  \
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...
# 3  ['допустить', 'выборы', 'опрос', 'последовател...
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...
#
#                                               tokens  Topic_NMF
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...          0
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...          2
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...          0
# 3  ['допустить', 'выборы', 'опрос', 'последовател...          0
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...          2

# %%
plt.hist(df['Topic_NMF'])
plt.xticks([0, 1, 2]);

# %%
topic_1 = df[df['Topic_NMF']==0]
topic_1.shape
# Out:
# (1760, 7)

# %%
topic_2 = df[df['Topic_NMF']==1]
topic_2.shape
# Out:
# (128, 7)

# %%
topic_3 = df[df['Topic_NMF']==2]
topic_3.shape
# Out:
# (406, 7)

# %%
textt = ''.join(w for w in topic_1.tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_2.tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_3.tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **2 темы: визуализация**

# %%
nmf = NMF(n_components=2, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(n_components=2, random_state=42)

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['партия', 'государственный', 'председатель', 'федерация', 'владимир', 'явлинский', 'россия', 'российский', 'президент', 'путин']
#
#
# Top 10 words for topic #1:
# ['мочь', 'призывать', 'геннадий', 'андреевич', 'репост', 'кпрф', 'га', 'зюганов', 'поход', 'ставить']

# %%
topic_values = nmf.transform(doc_term_matrix)
topic_values.shape
# Out:
# (2294, 2)

# %%
df['Topic_NMF'] = topic_values.argmax(axis=1)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  post_id  \
# 0             0           0    12103
# 1             1           1    12266
# 2             2           2    12228
# 3             3           3    12191
# 4             4           4    12183
#
#                                            post_text  \
# 0  Итак 2024 наступил и скоро выборы, за кого гол...
# 1  Последнего реального кандидата от оппозиции и ...
# 2  Минутка на оппозицию...\n⚡«Неllо, Еlеnа Zelens...
# 3  Не допущен к выборам, по опросам у него не бол...
# 4  Более не сможет быть кандидатом в Президенты -...
#
#                                            tokenized  \
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...
# 3  ['допустить', 'выборы', 'опрос', 'последовател...
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...
#
#                                               tokens  Topic_NMF
# 0  ['итак', 'наступить', 'скоро', 'выборы', 'кто'...          0
# 1  ['последний', 'реальный', 'кандидат', 'оппозиц...          0
# 2  ['минутка', 'оппозиция', 'еlеn', 'байден', 'пo...          0
# 3  ['допустить', 'выборы', 'опрос', 'последовател...          0
# 4  ['смочь', 'кандидат', 'президент', 'умереть', ...          0

# %%
plt.hist(df['Topic_NMF'])
plt.xticks([0, 1]);

# %%
topic_1 = df[df['Topic_NMF']==0]
topic_1.shape
# Out:
# (2040, 7)

# %%
topic_2 = df[df['Topic_NMF']==1]
topic_2.shape
# Out:
# (254, 7)

# %%
textt = ''.join(w for w in topic_1.tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_2.tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
topic_2
# Out:
#       Unnamed: 0.1  Unnamed: 0  post_id  \
# 240            240         370     5332
# 306            306         497     3385
# 331            331         532     3003
# 337            337         546     2925
# 368            368         584     2853
# ...            ...         ...      ...
# 2144          2144        2702      188
# 2180          2180        2747      139
# 2215          2215        2789       97
# 2253          2253        2833       52
# 2278          2278        2860       22
#
#                                               post_text  \
# 240   Навальный призывает бойкотировать выборы, а ка...
# 306   Голосование 2018 тут https://vk.com/vybory_pre...
# 331                                 Надо ставить походу
# 337                                 Надо ставить походу
# 368                                 Надо ставить походу
# ...                                                 ...
# 2144                                Надо ставить походу
# 2180                                Надо ставить походу
# 2215                                Надо ставить походу
# 2253                                Надо ставить походу
# 2278                                Надо ставить походу
#
#                                               tokenized  \
# 240   ['навальный', 'призывать', 'бойкотировать', 'в...
# 306   ['голосование', 'интернет', 'молодёжь', 'челов...
# 331                                ['ставить', 'поход']
# 337                                ['ставить', 'поход']
# 368                                ['ставить', 'поход']
# ...                                                 ...
# 2144                               ['ставить', 'поход']
# 2180                               ['ставить', 'поход']
# 2215                               ['ставить', 'поход']
# 2253                               ['ставить', 'поход']
# 2278                               ['ставить', 'поход']
#
#                                                  tokens  Topic_NMF
# 240   ['навальный', 'призывать', 'бойкотировать', 'в...          1
# 306   ['голосование', 'интернет', 'молодёжь', 'челов...          1
# 331                                ['ставить', 'поход']          1
# 337                                ['ставить', 'поход']          1
# 368                                ['ставить', 'поход']          1
# ...                                                 ...        ...
# 2144                               ['ставить', 'поход']          1
# 2180                               ['ставить', 'поход']          1
# 2215                               ['ставить', 'поход']          1
# 2253                               ['ставить', 'поход']          1
# 2278                               ['ставить', 'поход']          1
#
# [128 rows x 7 columns]

# %%
df.to_csv('posts_topic.csv')
