# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
df = pd.read_csv('pure_posts_tokens.csv',index_col=0)
df.head()
# Out:
#    post_id        date                                          post_text  \
# 0  2192617  2025-05-11  СМИ взбудоражены предложением Путина провести ...
# 2  2192574  2025-05-11  WSJ сообщила о признании Трампом сложности в р...
# 3  2192555  2025-05-11  ‼🇫🇷🇩🇪🇬🇧 Кто ж ездит к Зеленскому без допинга: ...
# 4  2192537  2025-05-11  Зеленский ответил на предложение Путина о пере...
# 6  2192508  2025-05-11  Фицо ответил на критику Каллас из-за визита в ...
#
#                                            tokenized  \
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...
# 2  ['wsj', 'сообщить', 'признание', 'трамп', 'сло...
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...
# 4  ['зеленский', 'ответить', 'предложение', 'пути...
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...
#
#                                          pure_tokens
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...
# 2  ['сообщить', 'признание', 'трамп', 'сложность'...
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...
# 4  ['зеленский', 'ответить', 'предложение', 'пути...
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...

# %% [markdown]
# **Латантное распределение Дирихле (LDA)**

# %%
count_vect = CountVectorizer(max_df=0.8, min_df=3, stop_words=None)
doc_term_matrix = count_vect.fit_transform(df['pure_tokens'].values.astype('U'))

# %% [markdown]
# **2 темы**

# %%
LDA_2 = LatentDirichletAllocation(n_components=2, random_state=42)
LDA_2.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA_2.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['европа', 'украина', 'победа', 'военный', 'российский', 'война', 'свой', 'наш', 'страна', 'россия']
#
#
# Top 10 words for topic #1:
# ['американский', 'свой', 'президент', 'киев', 'украинский', 'зеленский', 'россия', 'трамп', 'сша', 'украина']

# %% [markdown]
# **3 темы**

# %%
LDA_3 = LatentDirichletAllocation(n_components=3, random_state=42)
LDA_3.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42)

# %%
for i,topic in enumerate(LDA_3.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['май', 'москва', 'украина', 'европа', 'наш', 'победа', 'война', 'свой', 'страна', 'россия']
#
#
# Top 10 words for topic #1:
# ['американский', 'свой', 'президент', 'киев', 'украинский', 'россия', 'зеленский', 'трамп', 'сша', 'украина']
#
#
# Top 10 words for topic #2:
# ['направление', 'сила', 'войско', 'удар', 'военный', 'украинский', 'наш', 'российский', 'область', 'всу']

# %% [markdown]
# **4 темы**

# %%
LDA_4 = LatentDirichletAllocation(n_components=4, random_state=42)
LDA_4.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=4, random_state=42)

# %%
for i,topic in enumerate(LDA_4.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['президент', 'свой', 'конфликт', 'российский', 'военный', 'европа', 'страна', 'сша', 'украина', 'россия']
#
#
# Top 10 words for topic #1:
# ['президент', 'американский', 'свой', 'россия', 'киев', 'украинский', 'зеленский', 'сша', 'трамп', 'украина']
#
#
# Top 10 words for topic #2:
# ['сила', 'войско', 'направление', 'удар', 'военный', 'украинский', 'наш', 'российский', 'область', 'всу']
#
#
# Top 10 words for topic #3:
# ['наш', 'украина', 'москва', 'день', 'май', 'россия', 'страна', 'свой', 'война', 'победа']

# %% [markdown]
# **Лучшая модель: 2 темы**

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['европа', 'украина', 'победа', 'военный', 'российский', 'война', 'свой', 'наш', 'страна', 'россия']
#
#
# Top 10 words for topic #1:
# ['американский', 'свой', 'президент', 'киев', 'украинский', 'зеленский', 'россия', 'трамп', 'сша', 'украина']

# %%
topic_values = LDA.transform(doc_term_matrix)
topic_values.shape
# Out:
# (736, 2)

# %%
df['Topic_LDA'] = topic_values.argmax(axis=1)
df.head()
# Out:
#    post_id        date                                          post_text  \
# 0  2192617  2025-05-11  СМИ взбудоражены предложением Путина провести ...
# 2  2192574  2025-05-11  WSJ сообщила о признании Трампом сложности в р...
# 3  2192555  2025-05-11  ‼🇫🇷🇩🇪🇬🇧 Кто ж ездит к Зеленскому без допинга: ...
# 4  2192537  2025-05-11  Зеленский ответил на предложение Путина о пере...
# 6  2192508  2025-05-11  Фицо ответил на критику Каллас из-за визита в ...
#
#                                            tokenized  \
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...
# 2  ['wsj', 'сообщить', 'признание', 'трамп', 'сло...
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...
# 4  ['зеленский', 'ответить', 'предложение', 'пути...
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...
#
#                                          pure_tokens  Topic_LDA
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...          1
# 2  ['сообщить', 'признание', 'трамп', 'сложность'...          1
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...          0
# 4  ['зеленский', 'ответить', 'предложение', 'пути...          1
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...          0

# %%
plt.hist(df['Topic_LDA'])
plt.xticks([0, 1]);

# %%
topic_1 = df[df['Topic_LDA']==0]
topic_1.shape
# Out:
# (356, 6)

# %%
topic_2 = df[df['Topic_LDA']==1]
topic_2.shape
# Out:
# (380, 6)

# %%
textt = ''.join(w for w in topic_1.pure_tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_2.pure_tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **Неотрицательная матричная факторизация (NMF)**

# %%
tfidf_vect = TfidfVectorizer(max_df=1.0, min_df=2, stop_words=None)
doc_term_matrix = tfidf_vect.fit_transform(df['tokenized'].values.astype('U'))

# %% [markdown]
# **2 темы**

# %%
nmf = NMF(n_components=2, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(n_components=2, random_state=42)

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['год', 'киев', 'президент', 'который', 'зеленский', 'это', 'россия', 'сша', 'трамп', 'украина']
#
#
# Top 10 words for topic #1:
# ['войско', 'противник', 'техника', 'боец', 'курский', 'наш', 'направление', 'враг', 'область', 'всу']

# %% [markdown]
# **3 темы**

# %%
nmf = NMF(n_components=3, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(n_components=3, random_state=42)

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['крым', 'американский', 'киев', 'переговоры', 'президент', 'россия', 'зеленский', 'сша', 'украина', 'трамп']
#
#
# Top 10 words for topic #1:
# ['пехота', 'пункт', 'противник', 'боец', 'техника', 'курский', 'направление', 'враг', 'область', 'всу']
#
#
# Top 10 words for topic #2:
# ['свой', 'украина', 'европа', 'страна', 'россия', 'год', 'победа', 'который', 'война', 'это']

# %% [markdown]
# **3 темы: визуализация**

# %%
topic_values = nmf.transform(doc_term_matrix)
topic_values.shape
# Out:
# (736, 3)

# %%
df['Topic_NMF'] = topic_values.argmax(axis=1)
df.head()
# Out:
#    post_id        date                                          post_text  \
# 0  2192617  2025-05-11  СМИ взбудоражены предложением Путина провести ...
# 2  2192574  2025-05-11  WSJ сообщила о признании Трампом сложности в р...
# 3  2192555  2025-05-11  ‼🇫🇷🇩🇪🇬🇧 Кто ж ездит к Зеленскому без допинга: ...
# 4  2192537  2025-05-11  Зеленский ответил на предложение Путина о пере...
# 6  2192508  2025-05-11  Фицо ответил на критику Каллас из-за визита в ...
#
#                                            tokenized  \
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...
# 2  ['wsj', 'сообщить', 'признание', 'трамп', 'сло...
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...
# 4  ['зеленский', 'ответить', 'предложение', 'пути...
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...
#
#                                          pure_tokens  Topic_LDA  Topic_NMF
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...          1          0
# 2  ['сообщить', 'признание', 'трамп', 'сложность'...          1          0
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...          0          0
# 4  ['зеленский', 'ответить', 'предложение', 'пути...          1          0
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...          0          2

# %%
plt.hist(df['Topic_NMF'])
plt.xticks([0, 1, 2]);

# %%
topic_1 = df[df['Topic_NMF']==0]
topic_1.shape
# Out:
# (218, 7)

# %%
topic_2 = df[df['Topic_NMF']==1]
topic_2.shape
# Out:
# (166, 7)

# %%
topic_3 = df[df['Topic_NMF']==2]
topic_3.shape
# Out:
# (352, 7)

# %%
textt = ''.join(w for w in topic_1.pure_tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_2.pure_tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_3.pure_tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **2 темы: визуализация**

# %%
nmf = NMF(n_components=2, random_state=42)
nmf.fit(doc_term_matrix )
# Out:
# NMF(n_components=2, random_state=42)

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['год', 'киев', 'президент', 'который', 'зеленский', 'это', 'россия', 'сша', 'трамп', 'украина']
#
#
# Top 10 words for topic #1:
# ['войско', 'противник', 'техника', 'боец', 'курский', 'наш', 'направление', 'враг', 'область', 'всу']

# %%
topic_values = nmf.transform(doc_term_matrix)
topic_values.shape
# Out:
# (736, 2)

# %%
df['Topic_NMF'] = topic_values.argmax(axis=1)
df.head()
# Out:
#    post_id        date                                          post_text  \
# 0  2192617  2025-05-11  СМИ взбудоражены предложением Путина провести ...
# 2  2192574  2025-05-11  WSJ сообщила о признании Трампом сложности в р...
# 3  2192555  2025-05-11  ‼🇫🇷🇩🇪🇬🇧 Кто ж ездит к Зеленскому без допинга: ...
# 4  2192537  2025-05-11  Зеленский ответил на предложение Путина о пере...
# 6  2192508  2025-05-11  Фицо ответил на критику Каллас из-за визита в ...
#
#                                            tokenized  \
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...
# 2  ['wsj', 'сообщить', 'признание', 'трамп', 'сло...
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...
# 4  ['зеленский', 'ответить', 'предложение', 'пути...
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...
#
#                                          pure_tokens  Topic_LDA  Topic_NMF
# 0  ['сми', 'взбудоражить', 'предложение', 'путин'...          1          0
# 2  ['сообщить', 'признание', 'трамп', 'сложность'...          1          0
# 3  ['ездить', 'зеленский', 'допинг', 'войти', 'ку...          0          0
# 4  ['зеленский', 'ответить', 'предложение', 'пути...          1          0
# 6  ['фицо', 'ответить', 'критика', 'каллас', 'изз...          0          0

# %%
plt.hist(df['Topic_NMF'])
plt.xticks([0, 1]);

# %%
topic_1 = df[df['Topic_NMF']==0]
topic_1.shape
# Out:
# (538, 7)

# %%
topic_2 = df[df['Topic_NMF']==1]
topic_2.shape
# Out:
# (198, 7)

# %%
textt = ''.join(w for w in topic_1.pure_tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
textt = ''.join(w for w in topic_2.pure_tokens)
wordcloud = WordCloud().generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
topic_2
# Out:
#       Unnamed: 0.1  Unnamed: 0  post_id  \
# 240            240         370     5332
# 306            306         497     3385
# 331            331         532     3003
# 337            337         546     2925
# 368            368         584     2853
# ...            ...         ...      ...
# 2144          2144        2702      188
# 2180          2180        2747      139
# 2215          2215        2789       97
# 2253          2253        2833       52
# 2278          2278        2860       22
#
#                                               post_text  \
# 240   Навальный призывает бойкотировать выборы, а ка...
# 306   Голосование 2018 тут https://vk.com/vybory_pre...
# 331                                 Надо ставить походу
# 337                                 Надо ставить походу
# 368                                 Надо ставить походу
# ...                                                 ...
# 2144                                Надо ставить походу
# 2180                                Надо ставить походу
# 2215                                Надо ставить походу
# 2253                                Надо ставить походу
# 2278                                Надо ставить походу
#
#                                               tokenized  \
# 240   ['навальный', 'призывать', 'бойкотировать', 'в...
# 306   ['голосование', 'интернет', 'молодёжь', 'челов...
# 331                                ['ставить', 'поход']
# 337                                ['ставить', 'поход']
# 368                                ['ставить', 'поход']
# ...                                                 ...
# 2144                               ['ставить', 'поход']
# 2180                               ['ставить', 'поход']
# 2215                               ['ставить', 'поход']
# 2253                               ['ставить', 'поход']
# 2278                               ['ставить', 'поход']
#
#                                                  tokens  Topic_NMF
# 240   ['навальный', 'призывать', 'бойкотировать', 'в...          1
# 306   ['голосование', 'интернет', 'молодёжь', 'челов...          1
# 331                                ['ставить', 'поход']          1
# 337                                ['ставить', 'поход']          1
# 368                                ['ставить', 'поход']          1
# ...                                                 ...        ...
# 2144                               ['ставить', 'поход']          1
# 2180                               ['ставить', 'поход']          1
# 2215                               ['ставить', 'поход']          1
# 2253                               ['ставить', 'поход']          1
# 2278                               ['ставить', 'поход']          1
#
# [128 rows x 7 columns]

# %%
df.to_csv('posts_topic.csv')
